# %% [markdown]
# <a href="https://colab.research.google.com/github/hamza2803/Dastgyr_Case_Study/blob/main/DASTGYR__CASE_STUDY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Dastgyr_case_study/Dastgyr_data/Cancellation Reasons List Updated.csv', index_col=0)
df1
# Out:
#           cancellation_reason_id  \
# order_id
# 188424                        60
# 188420                        59
# 188401                        51
# 188401                        53
# 188396                        53
# ...                          ...
# 151200                        63
# 151195                        63
# 151182                        63
# 151182                        63
# 151173                        55
#
#                                         cancellation_reason
# order_id
# 188424    \rCustomer Has Already Purchased It From Somew...
# 188420            \rShop Closed And Customer Not Responding
# 188401                             \rSome SKUs were missing
# 188401                                      \rLate Delivery
# 188396                                      \rLate Delivery
# ...                                                     ...
# 151200     Order c cancel shop close death in family \rO...
# 151195      order cancel shop close not attend call \rOther
# 151182                               location issue \rOther
# 151182                               location issue \rOther
# 151173                                           \rSKU's NA
#
# [6064 rows x 2 columns]

# %%
# df1['cancel_reason_text'] = df1.cancel_reason_text.str.replace(np.nan, 'None')
df1['cancellation_reason'] = df1.cancellation_reason.fillna('')
df1.loc[df1['cancellation_reason'].str.contains('shop', case=False), 'cancellation_reason'] = 'Shop Close'
df1.loc[df1['cancellation_reason'].str.contains('cash', case=False), 'cancellation_reason'] = 'Cash Issue'
df1.loc[df1['cancellation_reason'].str.contains('payment', case=False), 'cancellation_reason'] = 'Cash Issue'
df1.loc[df1['cancellation_reason'].str.contains('location', case=False), 'cancellation_reason'] = 'Location Issue'
df1.loc[df1['cancellation_reason'].str.contains('area', case=False), 'cancellation_reason'] = 'Location Issue'
df1.loc[df1['cancellation_reason'].str.contains('road', case=False), 'cancellation_reason'] = 'Road Block'
df1.loc[df1['cancellation_reason'].str.contains('late', case=False), 'cancellation_reason'] = 'Late Delivery'

# %%
df1['cancellation_reason_id'].value_counts()
# Out:
# 57    1716
# 63    1436
# 55    1042
# 53     605
# 59     270
# 52     265
# 49     209
# 58     139
# 60     100
# 30      91
# 61      75
# 28      26
# 29      23
# 56      17
# 47      15
# 54      13
# 46       9
# 62       8
# 50       2
# 48       2
# 51       1
# Name: cancellation_reason_id, dtype: int64

# %%
# temp1 = df1.loc[df1['cancellation_reason_id'] == 63]
temp2 = df1['cancellation_reason'].value_counts()
temp2.to_frame()
# Out:
#                                                    cancellation_reason
# Shop Close                                                        1071
# \rSKU's NA                                                        1042
# Location Issue                                                    1007
# Late Delivery                                                      881
# Cash Issue                                                         734
# ...                                                                ...
#  Order Cancel due to not enter in cantt \rOther                      1
#  Order cancel due to no entrance in cantt \rOther                    1
#  order cancel order not deliver \rOther                              1
#  Rate Issue \rOther                                                  1
#  Wrongly punched by customer \rOther                                 1
#
# [173 rows x 1 columns]

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Dastgyr_case_study/Dastgyr_data/Cancellation Reasons.csv', index_col=0)
df2
# Out:
#                                                  Name  Complaint ID
# ID
# 46                                        Shop Closed             2
# 47                        Customer does not have cash             2
# 48                                              Other             2
# 49                                    Driver got late             3
# 50                                 Vehicle broke down             3
# 51                             Some SKUs were missing             3
# 52                                              Other             3
# 54                                 Vehicle broke down             4
# 56                               Damaged/short expiry             4
# 57                                              Other             4
# 62  Customer Claims That He Has Already Received T...             5
# 53                                      Late Delivery             4
# 55                                           SKU's NA             4
# 28                                   Incomplete Order             4
# 63                                              Other             5
# 64                                    Dukaan band thi             6
# 65              Dukaan daar ka rawaiya theek nahi tha             6
# 66                                              Other             6
# 58                        Customer Does Not Have Cash             5
# 59            Shop Closed And Customer Not Responding             5
# 60  Customer Has Already Purchased It From Somewhe...             5
# 61    Customer Claims That He Hasn't Placed The Order             5
# 29                                    No Service Area             4
# 31                              Agent Was Misbehaving             4
# 30                   Retailer's Location is Incorrect             4

# %% [markdown]
# agent

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Dastgyr_case_study/Dastgyr_data/Users.csv', index_col=0)
df2
# Out:
#                     Name  Gender  Is Active  Is Verify  Created At  Refer By  \
# ID
# 57769         Basit rauf     NaN       True       True  2020-10-30       NaN
# 57768         Kashif ali     NaN       True      False  2020-10-30       NaN
# 57767               Saad     NaN       True      False  2020-10-30       NaN
# 57766    muhammad nadeem     NaN       True      False  2020-10-30       NaN
# 57762      Faheem Sajid      NaN       True       True  2020-10-30       NaN
# ...                  ...     ...        ...        ...         ...       ...
# 146               Nadeem     NaN       True       True  2020-01-02       NaN
# 145                Afzal     NaN       True       True  2020-01-02       NaN
# 144                 Amir     NaN       True       True  2020-01-02       NaN
# 143               Rizwan     NaN       True       True  2020-01-02       NaN
# 142    Farhan bin Sajjad     NaN       True       True  2020-01-02       NaN
#
#       Refer At  Ref Code  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# ID
# 57769      NaN  211570.0         NaN          NaN          NaN          NaN
# 57768      NaN  576407.0         NaN          NaN          NaN          NaN
# 57767      NaN  527788.0         NaN          NaN          NaN          NaN
# 57766      NaN  297608.0         NaN          NaN          NaN          NaN
# 57762      NaN  218846.0         NaN          NaN          NaN          NaN
# ...        ...       ...         ...          ...          ...          ...
# 146        NaN       NaN         NaN          NaN          NaN          NaN
# 145        NaN       NaN         NaN          NaN          NaN          NaN
# 144        NaN       NaN         NaN          NaN          NaN          NaN
# 143        NaN       NaN         NaN          NaN          NaN          NaN
# 142        NaN       NaN         NaN          NaN          NaN          NaN
#
# [31880 rows x 12 columns]

# %%
temp2 = df2['Refer By'].value_counts()
temp2.to_frame()
# Out:
#          Refer By
# 16781.0       819
# 18871.0       565
# 20282.0       556
# 17205.0       455
# 46908.0       338
# ...           ...
# 37365.0         1
# 30765.0         1
# 11173.0         1
# 14846.0         1
# 27353.0         1
#
# [159 rows x 1 columns]

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Dastgyr_case_study/Dastgyr_data/Sales Agents Orders.csv', index_col=0)

# %%
temp2 = df3['agent_user_id'].value_counts()
temp2.to_frame()
# Out:
#        agent_user_id
# 20282            348
# 18871            277
# 45342            276
# 16781            275
# 37402            211
# 22515            186
# 46908            177
# 19311            176
# 17205            171
# 30836            157
# 11310            134
# 44736            132
# 46913            132
# 50780            113
# 43316            113
# 51496            112
# 16231            111
# 43427            107
# 46943            104
# 52140            102
# 47070            100
# 20773             96
# 53052             85
# 44742             72
# 53060             67
# 54689             60
# 49026             51
# 47067             50
# 43385             49
# 52138             39
# 11312             36
# 47353              8
# 44744              4
# 46901              4
# 45444              2
# 29351              2
# 30694              2

# %% [markdown]
# SKU

# %%
df4 = pd.read_csv('/content/drive/MyDrive/Dastgyr_case_study/Dastgyr_data/SKU.csv', index_col=0)
df5 = df4[(df4['Is Stock'] == True) & (df4['Is Active'] == True)]
df6 = df4[(df4['Is Stock'] == False) & (df4['Is Active'] == True)]

# %%
t2 = df5['Product ID'].value_counts()
t2.to_frame()
# Out:
#      Product ID
# 51           75
# 839          73
# 777          56
# 783          30
# 806          26
# ..          ...
# 276           1
# 273           1
# 245           1
# 172           1
# 849           1
#
# [238 rows x 1 columns]

# %%
t3 = df6['Product ID'].value_counts()
t3.to_frame()
# Out:
#      Product ID
# 773          18
# 7            15
# 359          13
# 148          10
# 350           9
# ..          ...
# 64            1
# 145           1
# 97            1
# 18            1
# 366           1
#
# [157 rows x 1 columns]

# %%
pd.merge(t2, t3, left_index=True, right_index=True)
# Out:
#      Product ID_x  Product ID_y
# 51             75             1
# 839            73             1
# 777            56             8
# 783            30             5
# 806            26             6
# ..            ...           ...
# 259             1             1
# 261             1             1
# 185             1             1
# 97              1             1
# 172             1             2
#
# [101 rows x 2 columns]
